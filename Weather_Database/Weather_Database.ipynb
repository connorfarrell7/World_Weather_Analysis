# %%
import random as rd
import numpy as np
from citipy import citipy
from config import wkey
import requests
import pandas as pd

# %%
lats = np.random.uniform(-90, 90, size=2000)
longs = np.random.uniform(-180, 180, size=2000)
lats_longs = zip(lats, longs)

coordinates = list(lats_longs)

cities = []

# %%
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 757

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + wkey

city_data = []

# %%
print("   Beginning Data Retrieval   ")
print("------------------------------")

record_count = 1

for i, city in enumerate(cities):
        
    city_url = url + "&q=" + city.replace(" ","+")

    print(f"Processing City {record_count} | {city}")
    
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":city_description})
    
    except:
        print("City not found. Skipping...")
        pass
    
print("------------------------------")
print("   Data Retrieval Complete    ")
print("------------------------------")
# Out:
#    Beginning Data Retrieval
# ------------------------------
# Processing City 1 | chokurdakh
# Processing City 2 | freetown
# Processing City 3 | leningradskiy
# Processing City 4 | bredasdorp
# Processing City 5 | ponta delgada
# Processing City 6 | ushuaia
# Processing City 7 | dakar
# Processing City 8 | la libertad
# Processing City 9 | kahului
# Processing City 10 | tuktoyaktuk
# Processing City 11 | esperance
# Processing City 12 | jamestown
# Processing City 13 | nikolskoye
# Processing City 14 | davidson
# Processing City 15 | namyslow
# Processing City 16 | cayenne
# Processing City 17 | new norfolk
# Processing City 18 | hobart
# Processing City 19 | rikitea
# Processing City 20 | barrow
# Processing City 21 | puerto ayora
# Processing City 22 | flinders
# Processing City 23 | bluff
# Processing City 24 | mahebourg
# Processing City 25 | khatanga
# Processing City 26 | port elizabeth
# Processing City 27 | barroualie
# City not found. Skipping...
# Processing City 28 | georgetown
# Processing City 29 | kollumerland
# City not found. Skipping...
# Processing City 30 | amderma
# City not found. Skipping...
# Processing City 31 | haines junction
# Processing City 32 | bethel
# Processing City 33 | asfi
# Processing City 34 | mys shmidta
# City not found. Skipping...
# Processing City 35 | vanimo
# Processing City 36 | dieppe bay
# City not found. Skipping...
# Processing City 37 | wanning
# Processing City 38 | chuy
# Processing City 39 | evensk
# Processing City 40 | mataura
# Processing City 41 | faanui
# Processing City 42 | albany
# Processing City 43 | yumen
# Processing City 44 | alekseyevka
# Processing City 45 | saint-leu
# Processing City 46 | mar del plata
# Processing City 47 | pishva
# Processing City 48 | anchorage
# Processing City 49 | hobyo
# Processing City 50 | trollhattan
# Processing City 51 | hermanus
# Processing City 52 | lososina
# Processing City 53 | cape town
# Processing City 54 | asau
# Processing City 55 | pevek
# Processing City 56 | kargil
# Processing City 57 | east london
# Processing City 58 | abaza
# Processing City 59 | tarata
# Processing City 60 | lebu
# Processing City 61 | punta arenas
# Processing City 62 | puyang
# Processing City 63 | muravlenko
# Processing City 64 | hambantota
# Processing City 65 | paramonga
# Processing City 66 | belushya guba
# City not found. Skipping...
# Processing City 67 | rethimnon
# Processing City 68 | bolungarvik
# City not found. Skipping...
# Processing City 69 | atar
# Processing City 70 | chara
# Processing City 71 | pinawa
# Processing City 72 | palmer
# Processing City 73 | hilo
# Processing City 74 | qaanaaq
# Processing City 75 | saint-joseph
# Processing City 76 | bubaque
# Processing City 77 | vaini
# Processing City 78 | hasaki
# Processing City 79 | singkang
# Processing City 80 | salinas
# Processing City 81 | sarahan
# Processing City 82 | ardesen
# Processing City 83 | barentsburg
# City not found. Skipping...
# Processing City 84 | springfield
# Processing City 85 | nizhneyansk
# City not found. Skipping...
# Processing City 86 | daur
# Processing City 87 | fort-shevchenko
# Processing City 88 | yellowknife
# Processing City 89 | kruisfontein
# Processing City 90 | west norriton
# Processing City 91 | luderitz
# Processing City 92 | tabou
# Processing City 93 | victoria
# Processing City 94 | san jeronimo
# Processing City 95 | champerico
# Processing City 96 | plainview
# Processing City 97 | ruatoria
# City not found. Skipping...
# Processing City 98 | vaitupu
# City not found. Skipping...
# Processing City 99 | curup
# Processing City 100 | harindanga
# Processing City 101 | iqaluit
# Processing City 102 | hithadhoo
# Processing City 103 | kabare
# Processing City 104 | humberto de campos
# Processing City 105 | amboasary
# Processing City 106 | khandyga
# Processing City 107 | moree
# Processing City 108 | illoqqortoormiut
# City not found. Skipping...
# Processing City 109 | the valley
# Processing City 110 | esna
# Processing City 111 | ilulissat
# Processing City 112 | gornopravdinsk
# Processing City 113 | grindavik
# Processing City 114 | caxito
# Processing City 115 | geraldton
# Processing City 116 | gouyave
# Processing City 117 | pozo colorado
# Processing City 118 | ponta do sol
# Processing City 119 | sioux lookout
# Processing City 120 | thompson
# Processing City 121 | ternate
# Processing City 122 | alta floresta
# Processing City 123 | cidreira
# Processing City 124 | taolanaro
# City not found. Skipping...
# Processing City 125 | nouadhibou
# Processing City 126 | shawville
# Processing City 127 | manjeshwar
# Processing City 128 | itarema
# Processing City 129 | tuatapere
# Processing City 130 | peranamallur
# Processing City 131 | castro
# Processing City 132 | altus
# Processing City 133 | bambanglipuro
# Processing City 134 | port alfred
# Processing City 135 | marawi
# Processing City 136 | bambous virieux
# Processing City 137 | kapaa
# Processing City 138 | rezh
# Processing City 139 | toamasina
# Processing City 140 | chernyshevskiy
# Processing City 141 | varhaug
# Processing City 142 | roald
# Processing City 143 | katherine
# Processing City 144 | innisfail
# Processing City 145 | shibetsu
# Processing City 146 | omboue
# Processing City 147 | rohtak
# Processing City 148 | coffs harbour
# Processing City 149 | los llanos de aridane
# Processing City 150 | airai
# Processing City 151 | porto novo
# Processing City 152 | suicheng
# Processing City 153 | norman wells
# Processing City 154 | paris
# Processing City 155 | klaksvik
# Processing City 156 | kawalu
# Processing City 157 | gariaband
# Processing City 158 | shimanovsk
# Processing City 159 | vila franca do campo
# Processing City 160 | rawah
# Processing City 161 | port-cartier
# Processing City 162 | ancud
# Processing City 163 | axim
# Processing City 164 | franklin
# Processing City 165 | eenhana
# Processing City 166 | cabra
# Processing City 167 | jackson
# Processing City 168 | panchgani
# Processing City 169 | pedras de fogo
# Processing City 170 | karnal
# Processing City 171 | porto walter
# Processing City 172 | taoudenni
# Processing City 173 | san cristobal
# Processing City 174 | katsuura
# Processing City 175 | artyk
# City not found. Skipping...
# Processing City 176 | mayo
# Processing City 177 | san patricio
# Processing City 178 | codrington
# Processing City 179 | rylsk
# Processing City 180 | ferkessedougou
# Processing City 181 | alofi
# Processing City 182 | candelaria
# Processing City 183 | waddan
# Processing City 184 | cabo san lucas
# Processing City 185 | muisne
# Processing City 186 | busselton
# Processing City 187 | road town
# Processing City 188 | nelson bay
# Processing City 189 | mangai
# Processing City 190 | umzimvubu
# City not found. Skipping...
# Processing City 191 | barguzin
# Processing City 192 | kapit
# Processing City 193 | avera
# Processing City 194 | toora-khem
# Processing City 195 | ribeira grande
# Processing City 196 | lagoa
# Processing City 197 | ulladulla
# Processing City 198 | pirmasens
# Processing City 199 | butaritari
# Processing City 200 | litoral del san juan
# City not found. Skipping...
# Processing City 201 | jieshi
# Processing City 202 | kodiak
# Processing City 203 | kaeo
# Processing City 204 | mehamn
# Processing City 205 | maria chiquita
# Processing City 206 | katangli
# Processing City 207 | pokhara
# Processing City 208 | beaverlodge
# Processing City 209 | dezful
# Processing City 210 | frontera
# Processing City 211 | ahipara
# Processing City 212 | hibbing
# Processing City 213 | samarai
# Processing City 214 | souillac
# Processing City 215 | maceio
# Processing City 216 | tarakan
# Processing City 217 | guerrero negro
# Processing City 218 | saskylakh
# Processing City 219 | sabha
# Processing City 220 | roros
# Processing City 221 | zhoucheng
# Processing City 222 | richards bay
# Processing City 223 | grand forks
# Processing City 224 | plastun
# Processing City 225 | attawapiskat
# City not found. Skipping...
# Processing City 226 | avarua
# Processing City 227 | rio gallegos
# Processing City 228 | shingu
# Processing City 229 | sola
# Processing City 230 | fortuna
# Processing City 231 | sakaiminato
# Processing City 232 | machali
# Processing City 233 | torbay
# Processing City 234 | chapleau
# Processing City 235 | provideniya
# Processing City 236 | dikson
# Processing City 237 | grand centre
# City not found. Skipping...
# Processing City 238 | mozarlandia
# Processing City 239 | goderich
# Processing City 240 | belmonte
# Processing City 241 | gazanjyk
# Processing City 242 | sangmelima
# Processing City 243 | bulawayo
# Processing City 244 | moindou
# Processing City 245 | isangel
# Processing City 246 | bonavista
# Processing City 247 | jamui
# Processing City 248 | mahina
# Processing City 249 | kirakira
# Processing City 250 | walvis bay
# Processing City 251 | snezhnogorsk
# Processing City 252 | tukrah
# Processing City 253 | gazojak
# Processing City 254 | saint-pierre
# Processing City 255 | niquelandia
# Processing City 256 | lisakovsk
# Processing City 257 | severodvinsk
# Processing City 258 | gat
# Processing City 259 | isilkul
# Processing City 260 | noumea
# Processing City 261 | neiafu
# Processing City 262 | tiznit
# Processing City 263 | nalut
# Processing City 264 | lorengau
# Processing City 265 | tasiilaq
# Processing City 266 | yabelo
# Processing City 267 | dudinka
# Processing City 268 | san quintin
# Processing City 269 | upernavik
# Processing City 270 | lasa
# Processing City 271 | warqla
# City not found. Skipping...
# Processing City 272 | paamiut
# Processing City 273 | ocos
# Processing City 274 | port lincoln
# Processing City 275 | saint-philippe
# Processing City 276 | hofn
# Processing City 277 | yarmouth
# Processing City 278 | hovd
# Processing City 279 | broken hill
# Processing City 280 | oussouye
# Processing City 281 | otjimbingwe
# Processing City 282 | soubre
# Processing City 283 | russell
# Processing City 284 | san andres
# Processing City 285 | paine
# Processing City 286 | namibe
# Processing City 287 | qingdao
# Processing City 288 | arraial do cabo
# Processing City 289 | nigran
# Processing City 290 | tsihombe
# City not found. Skipping...
# Processing City 291 | puerto baquerizo moreno
# Processing City 292 | tonj
# Processing City 293 | atuona
# Processing City 294 | pangody
# Processing City 295 | shimoda
# Processing City 296 | guatire
# Processing City 297 | dingle
# Processing City 298 | touros
# Processing City 299 | port hedland
# Processing City 300 | luena
# Processing City 301 | bathsheba
# Processing City 302 | mrirt
# City not found. Skipping...
# Processing City 303 | fukue
# Processing City 304 | toyooka
# Processing City 305 | cairns
# Processing City 306 | labytnangi
# Processing City 307 | calca
# Processing City 308 | talcahuano
# Processing City 309 | minab
# Processing City 310 | faya
# Processing City 311 | tessalit
# Processing City 312 | zhigansk
# Processing City 313 | havoysund
# Processing City 314 | saint george
# Processing City 315 | shache
# Processing City 316 | mega
# Processing City 317 | okitipupa
# Processing City 318 | azimur
# City not found. Skipping...
# Processing City 319 | zimovniki
# Processing City 320 | brae
# Processing City 321 | saleaula
# City not found. Skipping...
# Processing City 322 | cherdakly
# Processing City 323 | manaure
# Processing City 324 | labuhan
# Processing City 325 | gayeri
# Processing City 326 | saldanha
# Processing City 327 | vagay
# Processing City 328 | nueve de julio
# Processing City 329 | trinidad
# Processing City 330 | bonthe
# Processing City 331 | tadine
# Processing City 332 | marsh harbour
# Processing City 333 | samusu
# City not found. Skipping...
# Processing City 334 | balta
# Processing City 335 | carutapera
# Processing City 336 | namatanai
# Processing City 337 | vardo
# Processing City 338 | takoradi
# Processing City 339 | santana do livramento
# Processing City 340 | nanortalik
# Processing City 341 | biak
# Processing City 342 | sosnovo-ozerskoye
# Processing City 343 | elizabeth city
# Processing City 344 | cacahuatepec
# Processing City 345 | boden
# Processing City 346 | ornskoldsvik
# Processing City 347 | carnarvon
# Processing City 348 | hami
# Processing City 349 | assiniboia
# Processing City 350 | yulara
# Processing City 351 | pacific grove
# Processing City 352 | caravelas
# Processing City 353 | san benito
# Processing City 354 | kwinana
# Processing City 355 | tiksi
# Processing City 356 | omsukchan
# Processing City 357 | suisun city
# Processing City 358 | ilebo
# Processing City 359 | mangrol
# Processing City 360 | birao
# Processing City 361 | wajima
# Processing City 362 | kalmunai
# Processing City 363 | rognan
# Processing City 364 | oktyabrskiy
# Processing City 365 | meadow lake
# Processing City 366 | cap malheureux
# Processing City 367 | kaitangata
# Processing City 368 | sitka
# Processing City 369 | saint-augustin
# Processing City 370 | gandu
# Processing City 371 | felidhoo
# City not found. Skipping...
# Processing City 372 | rabo de peixe
# Processing City 373 | jonuta
# Processing City 374 | sentyabrskiy
# City not found. Skipping...
# Processing City 375 | chegdomyn
# Processing City 376 | camacha
# Processing City 377 | cockburn town
# Processing City 378 | mount isa
# Processing City 379 | sinnamary
# Processing City 380 | skoghall
# Processing City 381 | skjervoy
# Processing City 382 | kalmar
# Processing City 383 | dhidhdhoo
# Processing City 384 | pangnirtung
# Processing City 385 | kerman
# Processing City 386 | la palma
# Processing City 387 | bengkulu
# Processing City 388 | rabat
# Processing City 389 | guanare
# Processing City 390 | marcona
# City not found. Skipping...
# Processing City 391 | tumannyy
# City not found. Skipping...
# Processing City 392 | mutsamudu
# City not found. Skipping...
# Processing City 393 | mitsamiouli
# Processing City 394 | mikhaylovka
# Processing City 395 | sao jose da coroa grande
# Processing City 396 | ambilobe
# Processing City 397 | tulum
# Processing City 398 | leua
# Processing City 399 | kenai
# Processing City 400 | doctor pedro p. pena
# City not found. Skipping...
# Processing City 401 | pimentel
# Processing City 402 | labrea
# Processing City 403 | labutta
# City not found. Skipping...
# Processing City 404 | bandar-e lengeh
# Processing City 405 | sorland
# Processing City 406 | khuzdar
# Processing City 407 | palauig
# Processing City 408 | lamar
# Processing City 409 | napasar
# Processing City 410 | wewak
# Processing City 411 | kupang
# Processing City 412 | malwan
# City not found. Skipping...
# Processing City 413 | buin
# Processing City 414 | pisco
# Processing City 415 | jilib
# Processing City 416 | sept-iles
# Processing City 417 | dunedin
# Processing City 418 | grand river south east
# City not found. Skipping...
# Processing City 419 | tautira
# Processing City 420 | peleduy
# Processing City 421 | anadyr
# Processing City 422 | saint-georges
# Processing City 423 | sao felix do xingu
# Processing City 424 | dzhubga
# Processing City 425 | riviere-au-renard
# Processing City 426 | asosa
# Processing City 427 | jiaozuo
# Processing City 428 | severo-kurilsk
# Processing City 429 | coquimbo
# Processing City 430 | tindivanam
# Processing City 431 | sao filipe
# Processing City 432 | fano
# Processing City 433 | comodoro rivadavia
# Processing City 434 | batagay-alyta
# Processing City 435 | berezovyy
# Processing City 436 | midland
# Processing City 437 | vestmanna
# Processing City 438 | ibra
# Processing City 439 | champasak
# Processing City 440 | ust-nera
# Processing City 441 | harper
# Processing City 442 | veraval
# Processing City 443 | tawkar
# City not found. Skipping...
# Processing City 444 | sobolevo
# Processing City 445 | urumqi
# Processing City 446 | mananara
# Processing City 447 | batemans bay
# Processing City 448 | kyaikkami
# Processing City 449 | nome
# Processing City 450 | kavieng
# Processing City 451 | ndioum
# Processing City 452 | trairi
# Processing City 453 | veshkayma
# Processing City 454 | necochea
# Processing City 455 | antoniny
# Processing City 456 | sai buri
# Processing City 457 | okha
# Processing City 458 | yar-sale
# Processing City 459 | krasnoselkup
# Processing City 460 | clyde river
# Processing City 461 | brus laguna
# Processing City 462 | elliot
# Processing City 463 | nhulunbuy
# Processing City 464 | north bend
# Processing City 465 | ostrovnoy
# Processing City 466 | leh
# Processing City 467 | pilar
# Processing City 468 | kiruna
# Processing City 469 | namie
# Processing City 470 | beringovskiy
# Processing City 471 | alotenango
# Processing City 472 | te anau
# Processing City 473 | riobamba
# Processing City 474 | boueni
# Processing City 475 | kutum
# Processing City 476 | paharpur
# Processing City 477 | luwuk
# Processing City 478 | high level
# Processing City 479 | padang
# Processing City 480 | bijapur
# Processing City 481 | port-gentil
# Processing City 482 | bar harbor
# Processing City 483 | phan thiet
# Processing City 484 | henties bay
# Processing City 485 | tual
# Processing City 486 | kyshtovka
# Processing City 487 | tumwater
# Processing City 488 | ron
# Processing City 489 | saint-junien
# Processing City 490 | jiangmen
# Processing City 491 | laguna
# Processing City 492 | mount gambier
# Processing City 493 | sorong
# Processing City 494 | san joaquin
# Processing City 495 | satitoa
# City not found. Skipping...
# Processing City 496 | menongue
# Processing City 497 | aksu
# Processing City 498 | orodara
# Processing City 499 | kanye
# Processing City 500 | piste
# Processing City 501 | shumyachi
# Processing City 502 | quang ngai
# Processing City 503 | rungata
# City not found. Skipping...
# Processing City 504 | sorokino
# Processing City 505 | longyearbyen
# Processing City 506 | benguela
# Processing City 507 | shizunai
# Processing City 508 | dickson
# Processing City 509 | hamilton
# Processing City 510 | yangshe
# Processing City 511 | boralday
# Processing City 512 | batagay
# Processing City 513 | horodyshche
# Processing City 514 | quatre cocos
# Processing City 515 | kitzbuhel
# Processing City 516 | safwah
# City not found. Skipping...
# Processing City 517 | hsinchu
# Processing City 518 | bintulu
# Processing City 519 | guangyuan
# Processing City 520 | reze
# Processing City 521 | constitucion
# Processing City 522 | goose creek
# Processing City 523 | sao joao da barra
# Processing City 524 | banepa
# Processing City 525 | manokwari
# Processing City 526 | ormond beach
# Processing City 527 | khvorostyanka
# Processing City 528 | nyurba
# Processing City 529 | jalu
# Processing City 530 | perelyub
# Processing City 531 | deming
# Processing City 532 | valle de allende
# Processing City 533 | coahuayana
# Processing City 534 | villa carlos paz
# Processing City 535 | dixon
# Processing City 536 | kuragino
# Processing City 537 | cherskiy
# Processing City 538 | qaqortoq
# Processing City 539 | xining
# Processing City 540 | zandak
# Processing City 541 | jardim
# Processing City 542 | las choapas
# Processing City 543 | ugoofaaru
# Processing City 544 | acarau
# Processing City 545 | carmen
# Processing City 546 | fevralsk
# City not found. Skipping...
# Processing City 547 | palasbari
# Processing City 548 | waterloo
# Processing City 549 | sechura
# Processing City 550 | fairbanks
# Processing City 551 | morgantown
# Processing City 552 | banfora
# Processing City 553 | lolua
# City not found. Skipping...
# Processing City 554 | babu
# Processing City 555 | tura
# Processing City 556 | fonte boa
# Processing City 557 | nemuro
# Processing City 558 | mirnyy
# Processing City 559 | kariba
# Processing City 560 | ixtapa
# Processing City 561 | dzhebariki-khaya
# Processing City 562 | bolshoy tsaryn
# City not found. Skipping...
# Processing City 563 | kibaya
# Processing City 564 | shwebo
# Processing City 565 | balingasay
# Processing City 566 | demyanovo
# Processing City 567 | kasaragod
# Processing City 568 | santa isabel do rio negro
# Processing City 569 | ulaanbaatar
# Processing City 570 | huarmey
# Processing City 571 | panchagarh
# Processing City 572 | diffa
# Processing City 573 | arlit
# Processing City 574 | sabang
# Processing City 575 | cartagena
# Processing City 576 | indi
# Processing City 577 | saryshagan
# City not found. Skipping...
# Processing City 578 | magnor
# Processing City 579 | marsa matruh
# Processing City 580 | bima
# Processing City 581 | andevoranto
# City not found. Skipping...
# Processing City 582 | megion
# Processing City 583 | arman
# Processing City 584 | bilibino
# Processing City 585 | stupino
# Processing City 586 | plettenberg bay
# Processing City 587 | gondanglegi
# Processing City 588 | raga
# Processing City 589 | rockford
# Processing City 590 | husavik
# Processing City 591 | rawson
# Processing City 592 | port macquarie
# Processing City 593 | khani
# Processing City 594 | ajdabiya
# Processing City 595 | margate
# Processing City 596 | ola
# Processing City 597 | byron bay
# Processing City 598 | ca mau
# Processing City 599 | mandalgarh
# Processing City 600 | mvomero
# Processing City 601 | inhambane
# Processing City 602 | sheregesh
# Processing City 603 | ashdod
# Processing City 604 | dawlatabad
# Processing City 605 | warmbad
# Processing City 606 | balikpapan
# Processing City 607 | zolotinka
# City not found. Skipping...
# Processing City 608 | hopelchen
# Processing City 609 | reynosa
# Processing City 610 | puerto narino
# Processing City 611 | ambon
# Processing City 612 | general roca
# Processing City 613 | teguldet
# Processing City 614 | maldonado
# Processing City 615 | camacupa
# Processing City 616 | artyom
# Processing City 617 | deputatskiy
# Processing City 618 | durango
# Processing City 619 | san ramon de la nueva oran
# Processing City 620 | concepcion
# Processing City 621 | cangzhou
# Processing City 622 | parrita
# Processing City 623 | ostend
# Processing City 624 | espanola
# Processing City 625 | yeppoon
# Processing City 626 | abu samrah
# Processing City 627 | fuxin
# Processing City 628 | kipushi
# Processing City 629 | zyryanka
# Processing City 630 | chapais
# Processing City 631 | kamaishi
# Processing City 632 | inirida
# Processing City 633 | catamarca
# Processing City 634 | vostok
# Processing City 635 | sheridan
# Processing City 636 | taua
# Processing City 637 | alyangula
# Processing City 638 | agadir
# Processing City 639 | juneau
# Processing City 640 | bargal
# City not found. Skipping...
# Processing City 641 | yaan
# Processing City 642 | solnechnyy
# Processing City 643 | atasu
# Processing City 644 | punta alta
# Processing City 645 | auki
# Processing City 646 | liwale
# Processing City 647 | hays
# Processing City 648 | clarksdale
# Processing City 649 | constantine
# Processing City 650 | bandarbeyla
# Processing City 651 | gornyy
# Processing City 652 | salalah
# Processing City 653 | agadez
# Processing City 654 | barentu
# Processing City 655 | college
# Processing City 656 | vao
# Processing City 657 | yantai
# Processing City 658 | dong hoi
# Processing City 659 | nuevo progreso
# Processing City 660 | praia da vitoria
# Processing City 661 | lakatoro
# Processing City 662 | baykit
# Processing City 663 | vieste
# Processing City 664 | abu dhabi
# Processing City 665 | komsomolskiy
# Processing City 666 | kloulklubed
# Processing City 667 | houston
# Processing City 668 | manoel urbano
# Processing City 669 | sampit
# Processing City 670 | altamont
# Processing City 671 | vicente guerrero
# Processing City 672 | ordzhonikidze
# Processing City 673 | mazatlan
# Processing City 674 | san vicente
# Processing City 675 | chiang klang
# Processing City 676 | bitung
# Processing City 677 | arkhara
# Processing City 678 | artigas
# Processing City 679 | nizhniy kuranakh
# Processing City 680 | albesti
# Processing City 681 | turukhansk
# Processing City 682 | burnie
# Processing City 683 | mercedes
# Processing City 684 | barra patuca
# Processing City 685 | buqayq
# City not found. Skipping...
# Processing City 686 | orumiyeh
# Processing City 687 | adrar
# Processing City 688 | darnah
# Processing City 689 | iwanai
# Processing City 690 | trapani
# Processing City 691 | lebanon
# Processing City 692 | zacapoaxtla
# Processing City 693 | tazovskiy
# Processing City 694 | tarbagatay
# Processing City 695 | wuzhou
# Processing City 696 | pemba
# Processing City 697 | ossora
# Processing City 698 | kununurra
# Processing City 699 | pringsewu
# Processing City 700 | paso de los toros
# Processing City 701 | payakumbuh
# Processing City 702 | iquitos
# Processing City 703 | nicoya
# Processing City 704 | hirara
# Processing City 705 | kalawit
# Processing City 706 | pueblo nuevo
# Processing City 707 | meulaboh
# Processing City 708 | kedrovyy
# Processing City 709 | ilo
# Processing City 710 | neijiang
# Processing City 711 | yalta
# Processing City 712 | colares
# Processing City 713 | marzuq
# Processing City 714 | aklavik
# Processing City 715 | karratha
# Processing City 716 | sibu
# Processing City 717 | taksimo
# Processing City 718 | kailua
# Processing City 719 | zbarazh
# Processing City 720 | thinadhoo
# Processing City 721 | kargasok
# Processing City 722 | xuddur
# Processing City 723 | katra
# Processing City 724 | sterling
# Processing City 725 | bongaree
# Processing City 726 | cabedelo
# Processing City 727 | berwick
# Processing City 728 | kathmandu
# Processing City 729 | camopi
# Processing City 730 | soroca
# Processing City 731 | zhezkazgan
# Processing City 732 | moctezuma
# Processing City 733 | sembe
# Processing City 734 | tanete
# Processing City 735 | lata
# Processing City 736 | wufeng
# Processing City 737 | lavrentiya
# Processing City 738 | guymon
# Processing City 739 | gizo
# Processing City 740 | tienchung
# City not found. Skipping...
# Processing City 741 | baker city
# Processing City 742 | aden
# Processing City 743 | emirdag
# Processing City 744 | paragominas
# Processing City 745 | pantayivka
# Processing City 746 | salinopolis
# Processing City 747 | santa maria
# Processing City 748 | diego de almagro
# Processing City 749 | zhanatas
# City not found. Skipping...
# Processing City 750 | borlange
# City not found. Skipping...
# Processing City 751 | korla
# Processing City 752 | samalaeulu
# City not found. Skipping...
# Processing City 753 | kidal
# Processing City 754 | kyabram
# Processing City 755 | filingue
# Processing City 756 | cristalina
# Processing City 757 | lompoc
# ------------------------------
#    Data Retrieval Complete
# ------------------------------

# %%
len(city_data)
# Out:
# 708

# %%
weather_data_df = pd.DataFrame(city_data)
weather_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Chokurdakh      RU  70.6333  147.9167     54.00        52          55
# 1       Freetown      SL   8.4840  -13.2299     77.23        86         100
# 2  Leningradskiy      RU  69.3833  178.4167     34.93        93         100
# 3     Bredasdorp      ZA -34.5322   20.0403     40.32        93           0
# 4  Ponta Delgada      PT  37.7333  -25.6667     72.32        88          20
# 5        Ushuaia      AR -54.8000  -68.3000     38.86        65          40
# 6          Dakar      SN  14.6937  -17.4441     82.53        78          75
# 7    La Libertad      EC  -2.2333  -80.9000     73.06        78          75
# 8        Kahului      US  20.8947 -156.4700     85.96        76          40
# 9    Tuktoyaktuk      CA  69.4541 -133.0374     51.80        66          75
#
#    Wind Speed Current Description
# 0        8.21       broken clouds
# 1        6.73          light rain
# 2       14.92     overcast clouds
# 3        3.44           clear sky
# 4       13.80          few clouds
# 5       31.07    scattered clouds
# 6        6.91       broken clouds
# 7       10.36       broken clouds
# 8       20.71    scattered clouds
# 9       11.50       broken clouds

# %%
weather_data_df["Lat"] = weather_data_df["Lat"].map("{:.2f}".format)
weather_data_df["Lng"] = weather_data_df["Lng"].map("{:.2f}".format)
weather_data_df.head(10)
# Out:
#             City Country     Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0     Chokurdakh      RU   70.63   147.92     54.00        52          55
# 1       Freetown      SL    8.48   -13.23     77.23        86         100
# 2  Leningradskiy      RU   69.38   178.42     34.93        93         100
# 3     Bredasdorp      ZA  -34.53    20.04     40.32        93           0
# 4  Ponta Delgada      PT   37.73   -25.67     72.32        88          20
# 5        Ushuaia      AR  -54.80   -68.30     38.86        65          40
# 6          Dakar      SN   14.69   -17.44     82.53        78          75
# 7    La Libertad      EC   -2.23   -80.90     73.06        78          75
# 8        Kahului      US   20.89  -156.47     85.96        76          40
# 9    Tuktoyaktuk      CA   69.45  -133.04     51.80        66          75
#
#    Wind Speed Current Description
# 0        8.21       broken clouds
# 1        6.73          light rain
# 2       14.92     overcast clouds
# 3        3.44           clear sky
# 4       13.80          few clouds
# 5       31.07    scattered clouds
# 6        6.91       broken clouds
# 7       10.36       broken clouds
# 8       20.71    scattered clouds
# 9       11.50       broken clouds

# %%
weather_data_df.to_csv("WeatherPy_Database.csv", index=False)
